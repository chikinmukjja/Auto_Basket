# %%
import numpy as np
import pandas as pd

# %%
train = pd.read_excel("basket_data_overlap.xlsx")
train.head(3)
# Out:
#    left  right  frame  hog  x  y  x45  y45  hog2  x2  ...    x6  y6  x45_6  \
# 0     0      1      1    0  6 -2    0    0     1  -5  ...   -71   7    -37
# 1     0      1      2    0  3  6    3    0     1  -7  ...   -40 -12    -23
# 2     0      1      3    0  5  6    5    0     1  -4  ...     1   3      4
#
#    y45_6  hog7  x7  y7  x45_7  y45_7  lable
# 0     44     1 -13   5     -4     13      1
# 1      5     1  11  -9      0    -10      1
# 2      0     1  10   9      9      0      1
#
# [3 rows x 39 columns]

# %%
from sklearn.cross_validation import cross_val_score

feature_names = train.columns.drop('lable')
label_name = ['lable']

train_X = train[feature_names]
train_y = train[label_name]

# %%
train_X.head(3)
# Out:
#    left  right  frame  hog  x  y  x45  y45  hog2  x2  ...    hog6  x6  y6  \
# 0     0      1      1    0  6 -2    0    0     1  -5  ...       2 -71   7
# 1     0      1      2    0  3  6    3    0     1  -7  ...       1 -40 -12
# 2     0      1      3    0  5  6    5    0     1  -4  ...       1   1   3
#
#    x45_6  y45_6  hog7  x7  y7  x45_7  y45_7
# 0    -37     44     1 -13   5     -4     13
# 1    -23      5     1  11  -9      0    -10
# 2      4      0     1  10   9      9      0
#
# [3 rows x 38 columns]

# %%
train_y.head(3)
# Out:
#    lable
# 0      1
# 1      1
# 2      1

# %%
train_X.shape
# Out:
# (1474, 38)

# %%
train_y.shape
# Out:
# (1474, 1)

# %%
from sklearn.svm import LinearSVC
from sklearn.grid_search import GridSearchCV
from sklearn.svm import SVC

# %%
svc_param = {'C':np.logspace(-2,0,20)}
svc_rbf_param = [{'C':np.logspace(-2,0,15),"gamma":np.logspace(-2,0,15),'kernel': ['rbf']}]
svc_poly_param = [{'C':np.logspace(-2,0,15), 'gamma': np.logspace(-2,0,10), 'kernel': ['poly'], 'degree': [2,3,4,5]}]

# %% [markdown]
# ### find hypterparameter

# %%
gs_svc = GridSearchCV(LinearSVC(loss='l2'),svc_param,cv=5,n_jobs=4,verbose=1)

# %%
gs_svc.fit(np.array(train_X),np.array(train_y['lable']))
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\cross_validation.py:516: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of labels for any class cannot be less than n_folds=5.
#   % (min_labels, self.n_folds)), Warning)
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=4)]: Done 100 out of 100 | elapsed:    9.9s finished
# C:\Anaconda3\lib\site-packages\sklearn\svm\classes.py:197: DeprecationWarning: loss='l2' has been deprecated in favor of loss='squared_hinge' as of 0.16. Backward compatibility for the loss='l2' will be removed in 1.0
#   DeprecationWarning)
# GridSearchCV(cv=5, error_score='raise',
#        estimator=LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='l2', max_iter=1000, multi_class='ovr',
#      penalty='l2', random_state=None, tol=0.0001, verbose=0),
# ...

# %%
gs_svc_poly = GridSearchCV(SVC(), svc_poly_param,cv=5,n_jobs=4,verbose=1)

# %%
gs_svc_poly.fit(np.array(train_X),np.array(train_y['lable']))
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\cross_validation.py:516: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of labels for any class cannot be less than n_folds=5.
#   % (min_labels, self.n_folds)), Warning)
# Fitting 5 folds for each of 600 candidates, totalling 3000 fits
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=4)]: Done 192 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=4)]: Done 442 tasks      | elapsed:   33.7s
# [Parallel(n_jobs=4)]: Done 792 tasks      | elapsed:   55.3s
# [Parallel(n_jobs=4)]: Done 1242 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=4)]: Done 1792 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=4)]: Done 2442 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=4)]: Done 3000 out of 3000 | elapsed:  3.4min finished
# GridSearchCV(cv=5, error_score='raise',
#        estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
# ...

# %%
gs_svc_rbf = GridSearchCV(SVC(), svc_rbf_param,cv=5,n_jobs=4,verbose=1)

# %%
gs_svc_rbf.fit(np.array(train_X),np.array(train_y['lable']))
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\cross_validation.py:516: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of labels for any class cannot be less than n_folds=5.
#   % (min_labels, self.n_folds)), Warning)
# Fitting 5 folds for each of 225 candidates, totalling 1125 fits
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=4)]: Done 192 tasks      | elapsed:   11.4s
# [Parallel(n_jobs=4)]: Done 442 tasks      | elapsed:   25.1s
# [Parallel(n_jobs=4)]: Done 792 tasks      | elapsed:   45.7s
# [Parallel(n_jobs=4)]: Done 1125 out of 1125 | elapsed:  1.1min finished
# GridSearchCV(cv=5, error_score='raise',
#        estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False),
#        fit_params={}, iid=True, n_jobs=4,
# ...

# %% [markdown]
# ### result

# %%
print (gs_svc.best_params_, gs_svc.best_score_)
print (gs_svc_poly.best_params_, gs_svc_poly.best_score_)
print (gs_svc_rbf.best_params_, gs_svc_rbf.best_score_)
# Out:
# {'C': 0.033598182862837812} 0.782225237449
# {'C': 0.01, 'kernel': 'poly', 'gamma': 0.046415888336127774, 'degree': 2} 0.713704206242
# {'C': 1.0, 'kernel': 'rbf', 'gamma': 0.01} 0.468113975577

# %%
linear_scores = [x[1]*100 for x in gs_svc.grid_scores_]
poly_scores = [x[1]*100 for x in gs_svc_poly.grid_scores_]
rbf_scores = [x[1]*100 for x in gs_svc_rbf.grid_scores_]

# %%
import matplotlib.pyplot as plt
plt.plot(gs_svc.param_grid['C'],scores)
plt.axis([0, 1000, 50, 100])
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-35c781525283> in <module>()
#       1 import matplotlib.pyplot as plt
# ----> 2 plt.plot(gs_svc.param_grid['C'],scores)
#       3 plt.axis([0, 1000, 50, 100])
#       4 #plt.show()
#
# NameError: name 'scores' is not defined

# %%
clf = LinearSVC(C=gs_svc.best_params_['C'])
clf.fit(np.array(train_X),np.array(train_y['lable']))
# Out:
# LinearSVC(C=0.033598182862837812, class_weight=None, dual=True,
#      fit_intercept=True, intercept_scaling=1, loss='squared_hinge',
#      max_iter=1000, multi_class='ovr', penalty='l2', random_state=None,
#      tol=0.0001, verbose=0)

# %%
count = 0;
for i in train_X.index:
     if train_y.ix[i]['lable'] == clf.predict(np.array(train_X.ix[i])):
            count = count + 1
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Anaconda3\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Anaconda3\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# ...

# %%
print (count/len(train_X.index))
# Out:
# 0.903663500678426

# %%
clf = SVC(kernel='poly',C=gs_svc_poly.best_params_['C'],gamma=gs_svc_poly.best_params_['gamma'],degree=gs_svc_poly.best_params_['degree'])
clf.fit(np.array(train_X),np.array(train_y['lable']))
# Out:
# SVC(C=0.01, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=2, gamma=0.046415888336127774,
#   kernel='poly', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
count = 0;
for i in train_X.index:
     if train_y.ix[i]['lable'] == clf.predict(np.array(train_X.ix[i])):
            count = count + 1
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Anaconda3\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Anaconda3\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# ...

# %%
print (count/len(train_X.index))
# Out:
# 1.0

# %%
clf = SVC(kernel='rbf',C=gs_svc_rbf.best_params_['C'],gamma=gs_svc_rbf.best_params_['gamma'])
clf.fit(np.array(train_X),np.array(train_y['lable']))
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
count = 0;
for i in train_X.index:
     if train_y.ix[i]['lable'] == clf.predict(np.array(train_X.ix[i])):
            count = count + 1
# Out:
# C:\Anaconda3\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Anaconda3\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# C:\Anaconda3\lib\site-packages\sklearn\utils\validation.py:386: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and willraise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# ...

# %%
print (count/len(train_X.index))
# Out:
# 1.0
